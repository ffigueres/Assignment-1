# %%
m<-read.csv("mushrooms.data", header= FALSE, sep=",")

# %%
names(m) = c("poi")

# %%
m$poi = ifelse(m$poi == "e", "edible", "poisonous")

# %%
m
# Out:
#      poi       <NA> NA.1 NA.2 NA.3 NA.4 NA.5 NA.6 NA.7 NA.8 ... <NA> NA.1 NA.2
# 1    poisonous x    s    n    t    p    f    c    n    k    ... s    w    w
# 2    edible    x    s    y    t    a    f    c    b    k    ... s    w    w
# 3    edible    b    s    w    t    l    f    c    b    n    ... s    w    w
# 4    poisonous x    y    w    t    p    f    c    n    n    ... s    w    w
# 5    edible    x    s    g    f    n    f    w    b    k    ... s    w    w
# 6    edible    x    y    y    t    a    f    c    b    n    ... s    w    w
# 7    edible    b    s    w    t    a    f    c    b    g    ... s    w    w
# 8    edible    b    y    w    t    l    f    c    b    n    ... s    w    w
# 9    poisonous x    y    w    t    p    f    c    n    p    ... s    w    w
# 10   edible    b    s    y    t    a    f    c    b    g    ... s    w    w
# 11   edible    x    y    y    t    l    f    c    b    g    ... s    w    w
# ...
